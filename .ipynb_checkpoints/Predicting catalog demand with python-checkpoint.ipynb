# %% [markdown]
# # Predicting catalog demand with Python
# #### Continuation of Udacity project
#
# This project has been finished previously using Alteryx analytics software as project work for Udacity's Predictive Analytics for Business nanodegree.
# To practice using Python for predictive analytics we will go through this project again using scikit-learn and see how well our model performs.

# %% [markdown]
# ### Overview
#
# In this project, we will analyze a fictional business problem in the mail-order catalog business. We’re tasked with predicting how much money this company can expect to earn from sending out a catalog to new customers.
#
# This task will involve building logistic regression and linear regression models with scikit-learn and applying the results in order to provide a recommendation to management.
#
# We have two excel files to work with:
#     1. customers.xlsx - existing customers
#     2. mailinglist.xlsx - new customers

# %% [markdown]
# ### The Business Problem
#
# *Last year the company sent out its first print catalog, and is preparing to send out this year’s catalog in the coming months. The company has 250 new customers from their mailing list that they want to send the catalog to. Determine how much profit the company can expect from sending a catalog to these customers. Management does not want to send the catalog out to these new customers unless the expected profit contribution exceeds $10,000.*
#
# #### Business and Data Understanding
# 1. We need to predict if this catalog campaign is a good idea. Should the company send out these catalogs to new customers? How much revenue can this company expect to make if they send their new catalog to these 250 customers? Is it profitable considering all the costs and possibility that customer might not make a purchase at all?
# 2. What data is needed to inform those decisions?
#     - Possible revenue from each client
#     - Cost of each catalog
#     - Average past sales
#     - Average gross margin for each product
#     - Average number of products purchased
#     - Probability that customer will buy
#     - Customer segment

# %%
# Importing necessary libraries for exploratory data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### EDA

# %%
# Import data
customers = pd.read_excel('customers.xlsx')
customers.head(2)
# Out:
#             Name    Customer_Segment  Customer_ID           Address  \
# 0  Pamela Wright  Store Mailing List            2  376 S Jasmine St
# 1  Danell Valdez  Store Mailing List            7  12066 E Lake Cir
#
#                 City State    ZIP  Avg_Sale_Amount  Store_Number  \
# 0             Denver    CO  80224            227.9           100
# 1  Greenwood Village    CO  80111             55.0           105
#
#   Responded_to_Last_Catalog  Avg_Num_Products_Purchased  #_Years_as_Customer
# 0                        No                           1                    6
# 1                       Yes                           1                    6

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2375 entries, 0 to 2374
# Data columns (total 12 columns):
# Name                          2375 non-null object
# Customer_Segment              2375 non-null object
# Customer_ID                   2375 non-null int64
# Address                       2375 non-null object
# City                          2375 non-null object
# State                         2375 non-null object
# ZIP                           2375 non-null int64
# Avg_Sale_Amount               2375 non-null float64
# Store_Number                  2375 non-null int64
# Responded_to_Last_Catalog     2375 non-null object
# Avg_Num_Products_Purchased    2375 non-null int64
# #_Years_as_Customer           2375 non-null int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 222.8+ KB

# %%
customers.describe()
# Out:
#        Customer_ID           ZIP  Avg_Sale_Amount  Store_Number  \
# count  2375.000000   2375.000000      2375.000000   2375.000000
# mean   1647.845474  80123.333474       399.774093    104.297684
# std     962.728105    107.255770       340.115808      2.837240
# min       2.000000  80002.000000         1.220000    100.000000
# 25%     820.500000  80014.000000       168.925000    101.000000
# 50%    1629.000000  80123.000000       281.320000    105.000000
# 75%    2492.500000  80221.000000       572.400000    107.000000
# max    3335.000000  80640.000000      2963.490000    109.000000
#
#        Avg_Num_Products_Purchased  #_Years_as_Customer
# count                 2375.000000          2375.000000
# mean                     3.347368             4.500632
# std                      2.738568             2.309986
# min                      1.000000             1.000000
# 25%                      1.000000             2.000000
# 50%                      3.000000             5.000000
# 75%                      5.000000             6.000000
# max                     26.000000             8.000000

# %%
sns.pairplot(customers,hue='Responded_to_Last_Catalog')

# %%
customers['Responded_to_Last_Catalog'].value_counts()
# Out:
# No     2204
# Yes     171
# Name: Responded_to_Last_Catalog, dtype: int64

# %%
sns.countplot(customers['Responded_to_Last_Catalog'])

# %% [markdown]
# --- Features to consider in our model ---

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Avg_Num_Products_Purchased', y='Avg_Sale_Amount', data=customers, hue='Responded_to_Last_Catalog' ,height=6,aspect=1,fit_reg=True)

# %%
feats = customers.drop(['Name', 'Customer_ID', 'Address', 'City', 'State', 'ZIP'], axis=1)
feats.head(2)
# Out:
#      Customer_Segment  Avg_Sale_Amount  Store_Number  \
# 0  Store Mailing List            227.9           100
# 1  Store Mailing List             55.0           105
#
#   Responded_to_Last_Catalog  Avg_Num_Products_Purchased  #_Years_as_Customer
# 0                        No                           1                    6
# 1                       Yes                           1                    6

# %% [markdown]
# --- Convert Customer_Segment to dummy variables ---

# %%
feats['Customer_Segment'].value_counts()
# Out:
# Store Mailing List              1108
# Loyalty Club Only                579
# Credit Card Only                 494
# Loyalty Club and Credit Card     194
# Name: Customer_Segment, dtype: int64

# %%
seg_dummies = pd.get_dummies(feats['Customer_Segment'], prefix='Seg_', drop_first=True)

# %%
feats = pd.concat([feats, seg_dummies], axis=1)
feats = feats.drop('Customer_Segment', axis=1)
feats.head()
# Out:
#    Avg_Sale_Amount  Store_Number Responded_to_Last_Catalog  \
# 0           227.90           100                        No
# 1            55.00           105                       Yes
# 2           212.57           101                        No
# 3           195.31           105                       Yes
# 4           110.55           100                       Yes
#
#    Avg_Num_Products_Purchased  #_Years_as_Customer  Seg__Loyalty Club Only  \
# 0                           1                    6                       0
# 1                           1                    6                       0
# 2                           1                    3                       0
# 3                           1                    6                       0
# 4                           1                    2                       0
#
#    Seg__Loyalty Club and Credit Card  Seg__Store Mailing List
# 0                                  0                        1
# 1                                  0                        1
# 2                                  0                        1
# 3                                  0                        1
# 4                                  0                        1

# %%
# Convert customers' response to last catalog to 1 or 0 if they did not answer 
def converter(response):
    if response == 'Yes':
        return 1
    else:
        return 0

feats['Answer_Yes'] = feats['Responded_to_Last_Catalog'].apply(converter)

feats = feats.drop('Responded_to_Last_Catalog', axis=1)
feats.head(2)
# Out:
#    Avg_Sale_Amount  Store_Number  Avg_Num_Products_Purchased  \
# 0            227.9           100                           1
# 1             55.0           105                           1
#
#    #_Years_as_Customer  Seg__Loyalty Club Only  \
# 0                    6                       0
# 1                    6                       0
#
#    Seg__Loyalty Club and Credit Card  Seg__Store Mailing List  Answer_Yes
# 0                                  0                        1           0
# 1                                  0                        1           1

# %% [markdown]
# --- Because our data is skewed towards 'No' we will balance the classes manually ---

# %%
my_train = pd.DataFrame(feats[feats['Answer_Yes']==1])

# %%
no_answer = pd.DataFrame(feats[feats['Answer_Yes']==0]).sample(n=171, random_state=101)

# %%
my_train = pd.concat([my_train, no_answer], axis=0)

# %%
my_train['Answer_Yes'].value_counts()
# Out:
# 1    171
# 0    171
# Name: Answer_Yes, dtype: int64

# %%
sns.countplot(my_train['Answer_Yes'])

# %% [markdown]
#
# ## Logistic Regression
# Because we first need to find the probability of customers responding to the catalog based on previous data, we will use a logistic regression model to do that.  Logistic regression will give us a probability between 0 and 1 that the customer will respond to our catalog.

# %%
from sklearn.model_selection import train_test_split

# %%
X = my_train.drop(['Answer_Yes', 'Avg_Sale_Amount'], axis=1)
y = my_train['Answer_Yes']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# --- Train and fit a logistic regression model on the training set ---

# %%
from sklearn.linear_model import LogisticRegression

# %%
logr = LogisticRegression()
logr.fit(X_train, y_train)
# Out:
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# --- Predict values for the testing data ---

# %%
predictions = logr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[32 23]
#  [10 38]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.58      0.66        55
#            1       0.62      0.79      0.70        48
#
#     accuracy                           0.68       103
#    macro avg       0.69      0.69      0.68       103
# weighted avg       0.70      0.68      0.68       103

# %% [markdown]
# # Try GridSearch

# %% [markdown]
# Lets see if we can get better results on our Logistic Regression model with GridSearch.

# %%
param_grid = {'solver':['newton-cg', 'lbfgs', 'liblinear', 'saga'], 'C': [0.1, 1, 10, 100]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(logr, param_grid, refit=True, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, solver=newton-cg .........................................
# [CV] ............. C=0.1, solver=newton-cg, score=0.650, total=   0.0s
# [CV] C=0.1, solver=newton-cg .........................................
# [CV] ............. C=0.1, solver=newton-cg, score=0.675, total=   0.0s
# [CV] C=0.1, solver=newton-cg .........................................
# [CV] ............. C=0.1, solver=newton-cg, score=0.759, total=   0.0s
# [CV] C=0.1, solver=lbfgs .............................................
# [CV] ................. C=0.1, solver=lbfgs, score=0.650, total=   0.0s
# [CV] C=0.1, solver=lbfgs .............................................
# [CV] ................. C=0.1, solver=lbfgs, score=0.675, total=   0.0s
# [CV] C=0.1, solver=lbfgs .............................................
# [CV] ................. C=0.1, solver=lbfgs, score=0.759, total=   0.0s
# [CV] C=0.1, solver=liblinear .........................................
# [CV] ............. C=0.1, solver=liblinear, score=0.650, total=   0.0s
# [CV] C=0.1, solver=liblinear .........................................
# [CV] ............. C=0.1, solver=liblinear, score=0.688, total=   0.0s
# [CV] C=0.1, solver=liblinear .........................................
# [CV] ............. C=0.1, solver=liblinear, score=0.759, total=   0.0s
# [CV] C=0.1, solver=saga ..............................................
# [CV] .................. C=0.1, solver=saga, score=0.675, total=   0.0s
# [CV] C=0.1, solver=saga ..............................................
# [CV] .................. C=0.1, solver=saga, score=0.662, total=   0.0s
# [CV] C=0.1, solver=saga ..............................................
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# [CV] .................. C=0.1, solver=saga, score=0.722, total=   0.0s
# [CV] C=1, solver=newton-cg ...........................................
# [CV] ............... C=1, solver=newton-cg, score=0.625, total=   0.0s
# [CV] C=1, solver=newton-cg ...........................................
# [CV] ............... C=1, solver=newton-cg, score=0.688, total=   0.1s
# [CV] C=1, solver=newton-cg ...........................................
# [CV] ............... C=1, solver=newton-cg, score=0.772, total=   0.0s
# [CV] C=1, solver=lbfgs ...............................................
# [CV] ................... C=1, solver=lbfgs, score=0.625, total=   0.0s
# [CV] C=1, solver=lbfgs ...............................................
# [CV] ................... C=1, solver=lbfgs, score=0.688, total=   0.0s
# [CV] C=1, solver=lbfgs ...............................................
# [CV] ................... C=1, solver=lbfgs, score=0.772, total=   0.0s
# [CV] C=1, solver=liblinear ...........................................
# [CV] ............... C=1, solver=liblinear, score=0.637, total=   0.0s
# [CV] C=1, solver=liblinear ...........................................
# [CV] ............... C=1, solver=liblinear, score=0.688, total=   0.0s
# [CV] C=1, solver=liblinear ...........................................
# [CV] ............... C=1, solver=liblinear, score=0.772, total=   0.0s
# [CV] C=1, solver=saga ................................................
# [CV] .................... C=1, solver=saga, score=0.675, total=   0.0s
# [CV] C=1, solver=saga ................................................
# [CV] .................... C=1, solver=saga, score=0.662, total=   0.0s
# [CV] C=1, solver=saga ................................................
# [CV] .................... C=1, solver=saga, score=0.722, total=   0.0s
# [CV] C=10, solver=newton-cg ..........................................
# [CV] .............. C=10, solver=newton-cg, score=0.650, total=   0.1s
# [CV] C=10, solver=newton-cg ..........................................
# [CV] .............. C=10, solver=newton-cg, score=0.700, total=   0.0s
# [CV] C=10, solver=newton-cg ..........................................
# [CV] .............. C=10, solver=newton-cg, score=0.772, total=   0.0s
# [CV] C=10, solver=lbfgs ..............................................
# [CV] .................. C=10, solver=lbfgs, score=0.650, total=   0.0s
# [CV] C=10, solver=lbfgs ..............................................
# [CV] .................. C=10, solver=lbfgs, score=0.700, total=   0.0s
# [CV] C=10, solver=lbfgs ..............................................
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [CV] .................. C=10, solver=lbfgs, score=0.772, total=   0.0s
# [CV] C=10, solver=liblinear ..........................................
# [CV] .............. C=10, solver=liblinear, score=0.650, total=   0.0s
# [CV] C=10, solver=liblinear ..........................................
# [CV] .............. C=10, solver=liblinear, score=0.700, total=   0.0s
# [CV] C=10, solver=liblinear ..........................................
# [CV] .............. C=10, solver=liblinear, score=0.772, total=   0.0s
# [CV] C=10, solver=saga ...............................................
# [CV] ................... C=10, solver=saga, score=0.675, total=   0.0s
# [CV] C=10, solver=saga ...............................................
# [CV] ................... C=10, solver=saga, score=0.662, total=   0.0s
# [CV] C=10, solver=saga ...............................................
# [CV] ................... C=10, solver=saga, score=0.722, total=   0.0s
# [CV] C=100, solver=newton-cg .........................................
# [CV] ............. C=100, solver=newton-cg, score=0.650, total=   0.1s
# [CV] C=100, solver=newton-cg .........................................
# [CV] ............. C=100, solver=newton-cg, score=0.700, total=   0.0s
# [CV] C=100, solver=newton-cg .........................................
# [CV] ............. C=100, solver=newton-cg, score=0.772, total=   0.0s
# [CV] C=100, solver=lbfgs .............................................
# [CV] ................. C=100, solver=lbfgs, score=0.650, total=   0.0s
# [CV] C=100, solver=lbfgs .............................................
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# [CV] ................. C=100, solver=lbfgs, score=0.700, total=   0.0s
# [CV] C=100, solver=lbfgs .............................................
# [CV] ................. C=100, solver=lbfgs, score=0.772, total=   0.0s
# [CV] C=100, solver=liblinear .........................................
# [CV] ............. C=100, solver=liblinear, score=0.650, total=   0.0s
# [CV] C=100, solver=liblinear .........................................
# [CV] ............. C=100, solver=liblinear, score=0.700, total=   0.0s
# [CV] C=100, solver=liblinear .........................................
# [CV] ............. C=100, solver=liblinear, score=0.772, total=   0.0s
# [CV] C=100, solver=saga ..............................................
# [CV] .................. C=100, solver=saga, score=0.675, total=   0.0s
# [CV] C=100, solver=saga ..............................................
# [CV] .................. C=100, solver=saga, score=0.662, total=   0.0s
# [CV] C=100, solver=saga ..............................................
# [CV] .................. C=100, solver=saga, score=0.722, total=   0.0s
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    1.0s finished
# /Users/helenahook/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='warn',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'saga']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 10, 'solver': 'newton-cg'}

# %% [markdown]
# --- Predict values for the testing data with GridSearch parameters ---

# %%
grid_predictions = grid.predict(X_test)

# %% [markdown]
# --- GridSearch improved our model slightly ---

# %%
print(confusion_matrix(y_test, grid_predictions))
print('\n')
print(classification_report(y_test, grid_predictions))
# Out:
# [[32 23]
#  [ 8 40]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.58      0.67        55
#            1       0.63      0.83      0.72        48
#
#     accuracy                           0.70       103
#    macro avg       0.72      0.71      0.70       103
# weighted avg       0.72      0.70      0.70       103

# %% [markdown]
# ### Predict new customers responding to catalog

# %% [markdown]
# --- Now with this model we can predict the probability of our new customers responding to our catalog ---

# %%
new_customers = pd.read_excel('mailinglist_no_probs.xlsx')
new_customers.head(2)
# Out:
#            Name              Customer_Segment  Customer_ID            Address  \
# 0    A Giametti             Loyalty Club Only         2213  5326 S Lisbon Way
# 1  Abby Pierson  Loyalty Club and Credit Card         2785  4344 W Roanoke Pl
#
#          City State    ZIP  Store_Number  Avg_Num_Products_Purchased  \
# 0  Centennial    CO  80015           105                           3
# 1      Denver    CO  80236           101                           6
#
#    #_Years_as_Customer
# 0                  0.2
# 1                  0.6

# %% [markdown]
# --- Define the variables ---

# %%
feats_n = new_customers.drop(['Name', 'Customer_ID', 'Address', 'City', 'State', 'ZIP'], axis=1)
feats_n.head(2)
# Out:
#                Customer_Segment  Store_Number  Avg_Num_Products_Purchased  \
# 0             Loyalty Club Only           105                           3
# 1  Loyalty Club and Credit Card           101                           6
#
#    #_Years_as_Customer
# 0                  0.2
# 1                  0.6

# %% [markdown]
# --- Convert Customer_Segment to dummy variables ---

# %%
seg_dummies_n = pd.get_dummies(feats_n['Customer_Segment'], prefix='Seg_', drop_first=True)

# %%
feats_n = pd.concat([feats_n, seg_dummies_n], axis=1)
feats_n = feats_n.drop('Customer_Segment', axis=1)
feats_n.head(2)
# Out:
#    Store_Number  Avg_Num_Products_Purchased  #_Years_as_Customer  \
# 0           105                           3                  0.2
# 1           101                           6                  0.6
#
#    Seg__Loyalty Club Only  Seg__Loyalty Club and Credit Card  \
# 0                       1                                  0
# 1                       0                                  1
#
#    Seg__Store Mailing List
# 0                        0
# 1                        0

# %% [markdown]
# --- Predict the probability of new customers responding ---

# %%
predictions = grid.predict(feats_n)

# %%
probs = grid.predict_proba(feats_n)
grid.classes_
# Out:
# array([0, 1])

# %%
df_prob = pd.DataFrame(probs,columns=grid.classes_)
df_prob.head()
# Out:
#           0         1
# 0  0.885523  0.114477
# 1  0.892756  0.107244
# 2  0.972480  0.027520
# 3  0.835715  0.164285
# 4  0.919212  0.080788

# %%
feats_n = pd.concat([feats_n, df_prob[1]], axis=1)
# Rename response to catalog probability to 'Answer_Yes'
feats_n.rename(columns={1: 'Answer_Yes'}, inplace=True)
feats_n.head(2)
# Out:
#    Store_Number  Avg_Num_Products_Purchased  #_Years_as_Customer  \
# 0           105                           3                  0.2
# 1           101                           6                  0.6
#
#    Seg__Loyalty Club Only  Seg__Loyalty Club and Credit Card  \
# 0                       1                                  0
# 1                       0                                  1
#
#    Seg__Store Mailing List  Answer_Yes
# 0                        0    0.114477
# 1                        0    0.107244

# %% [markdown]
# # ----TOO LOW MEAN

# %%
feats_n['Answer_Yes'].describe()
# Out:
# count    250.000000
# mean       0.171391
# std        0.175046
# min        0.000030
# 25%        0.075479
# 50%        0.114477
# 75%        0.189308
# max        0.773792
# Name: Answer_Yes, dtype: float64

# %% [markdown]
#
# # Linear regression

# %% [markdown]
# We will use Avg_Sale_Amount from old customers' data to predict the average sale amount for new customers.

# %%
sns.lmplot(x='Avg_Num_Products_Purchased', y='Avg_Sale_Amount', data=customers)

# %% [markdown]
# --- Train and fit a logistic regression model on the training set ---

# %%
X = feats.drop(['Avg_Sale_Amount', '#_Years_as_Customer', 'Answer_Yes', 'Store_Number'], axis=1)
y = feats['Avg_Sale_Amount']

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
lm = LinearRegression()
lm.fit(X_train,y_train)
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                    Coefficient
# Avg_Num_Products_Purchased           70.681137
# Seg__Loyalty Club Only             -144.328199
# Seg__Loyalty Club and Credit Card   267.641604
# Seg__Store Mailing List            -231.327277

# %%
lm.intercept_
# Out:
# 284.480521108522

# %% [markdown]
# **Best linear regression equation**
# Y = 284.48 + 70.68 * Avg_Num_Products_Purchased - 144.33 * (If Type: Loyalty Club Only) + 267.64 * (If Type: Loyalty Club and Credit Card) - 231.33 * (If Type: Store Mailing List) + 0 * (If Type: Credit Card Only)

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions))) # check this
# Out:
# MAE: 89.31308194968375
# MSE: 17006.43868059899
# RMSE: 130.40873697954055

# %%
feats['Avg_Sale_Amount'].describe()
# Out:
# count    2375.000000
# mean      399.774093
# std       340.115808
# min         1.220000
# 25%       168.925000
# 50%       281.320000
# 75%       572.400000
# max      2963.490000
# Name: Avg_Sale_Amount, dtype: float64

# %% [markdown]
# ### Lets predict the average sale amount for new customers with our Linear Regression model

# %%
X_n = feats_n.drop(['#_Years_as_Customer', 'Answer_Yes', 'Store_Number'], axis=1)
lm_pred = lm.predict(X_n)

# %%
lm_predictions = pd.DataFrame(lm_pred,columns=['Predicted_Avg_Sale_Amount'])
lm_predictions.head(3)
# Out:
#    Predicted_Avg_Sale_Amount
# 0                 352.195733
# 1                 976.208946
# 2                 634.920280

# %% [markdown]
# **Then we multiply the predicted revenue with given customer’s probability of making the purchase:**
# Probable Revenue = (Predicted_Revenue) * (Probability to buy)
# *(Probable_Revenue = (Predicted_Avg_Sale_Amount) * (Answer_Yes))*

# %%
# Concatenate new customers' Predicted_Avg_Sale_Amount to Answer_Yes
prob_revenue = pd.concat([feats_n['Answer_Yes'], lm_predictions], axis=1)
prob_revenue.head(2)
# Out:
#    Answer_Yes  Predicted_Avg_Sale_Amount
# 0    0.114477                 352.195733
# 1    0.107244                 976.208946

# %%
prob_revenue['Prob_Revenue'] = np.multiply(prob_revenue['Answer_Yes'], prob_revenue['Predicted_Avg_Sale_Amount'])
prob_revenue.head(2)
# Out:
#    Answer_Yes  Predicted_Avg_Sale_Amount  Prob_Revenue
# 0    0.114477                 352.195733     40.318238
# 1    0.107244                 976.208946    104.692292

# %%
prob_revenue['Prob_Revenue'].describe()
# Out:
# count    250.000000
# mean      70.950215
# std       47.631051
# min        0.074750
# 25%       33.442889
# 50%       45.903881
# 75%      110.465087
# max      252.272603
# Name: Prob_Revenue, dtype: float64

# %% [markdown]
# This is multiplied with average gross margin of all products, which is 50%
# and deduct the cost of each catalog which is $6.50:
# Probable_Revenue * 0.5 – 6.50

# %% [markdown]
# # the real outcome cause of fake data

# %%
prob_revenue['Rev_Minus_cost'] = (prob_revenue['Prob_Revenue']*0.5)-6.50
prob_revenue['Rev_Minus_cost'].sum()
# Out:
# 7243.776901506162
